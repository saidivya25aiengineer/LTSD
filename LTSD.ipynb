# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Om Vighna Ganapathi Namo Namaha
# Om Gham Ganapathaaya Namaha
# Om Lambhodharaaya Namaha

# %% [markdown]
# # Lists

# %%
l1 = [1,2,3,45]
l1
# Out:
# [1, 2, 3, 45]

# %%
l1.append(89)

# %%
l1
# Out:
# [1, 2, 3, 45, 89]

# %%
l2 = l1.copy()

# %%
l2
# Out:
# [1, 2, 3, 45, 89]

# %%
l2.count(6)
# Out:
# 0

# %%
45 in l1
# Out:
# True

# %%
l2.extend([6,8,9,19])

# %%
l2
# Out:
# [1, 2, 3, 45, 89, 6, 8, 9, 19]

# %%
l2.index(89)
# Out:
# 4

# %%
l2.insert(0,9)

# %%
l2
# Out:
# [9, 1, 2, 3, 45, 89, 6, 8, 9, 19]

# %%
l2.pop(1)
# Out:
# 1

# %%
l2
# Out:
# [9, 2, 3, 45, 89, 6, 8, 9, 19]

# %%
l2.remove(8)

# %%
l2
# Out:
# [9, 2, 3, 45, 89, 6, 9, 19]

# %%
l2.reverse()

# %%
l2
# Out:
# [19, 9, 6, 89, 45, 3, 2, 9]

# %%
l2.sort()

# %%
l2
# Out:
# [2, 3, 6, 9, 9, 19, 45, 89]

# %%
l2.remove(19)

# %%
l2
# Out:
# [2, 3, 6, 9, 9, 45, 89]

# %%
l2.clear()

# %%
l2
# Out:
# []

# %% [markdown]
# # Tuples

# %%
tup1 = 23, 47, 89, 9

# %%
type(tup1)
# Out:
# tuple

# %%
tup1.count(23)
# Out:
# 1

# %%
tup1.index(89)
# Out:
# 2

# %%
1 in tup1
# Out:
# False

# %%
n1, n2, n3, n4 = tup1

# %%
n1
# Out:
# 23

# %%
n2
# Out:
# 47

# %%
n3
# Out:
# 89

# %%
n4
# Out:
# 9

# %% [markdown]
# # Sets

# %%
set1 = {23, 47, 89, 9}
set2 = {'abcdep'}

# %%
set1 & set2
# Out:
# set()

# %%
set1 ^ set2
# Out:
# {23, 47, 89, 9, 'abcdep'}

# %%
set2
# Out:
# {'abcdep'}

# %%
set3 = set('aeiou')

# %%
set3
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %%
set2 | set3
# Out:
# {'a', 'abcdep', 'e', 'i', 'o', 'u'}

# %%
set2 - set3
# Out:
# {'abcdep'}

# %%
set2 ^ set3
# Out:
# {'a', 'abcdep', 'e', 'i', 'o', 'u'}

# %%
set2 & set3
# Out:
# set()

# %%
set1.add(9)

# %%
set1
# Out:
# {9, 23, 47, 89}

# %%
set2
# Out:
# {'abcdep'}

# %%
set2.difference(set3)
# Out:
# {'abcdep'}

# %%
set3.difference(set2)
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %%
set2.difference_update(set3)

# %%
set2
# Out:
# {'abcdep'}

# %%
set3
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %%
set4 = set3.copy()

# %%
set4
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %%
set3.discard('n')

# %%
set3
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %%
set3.discard('e')

# %%
set3
# Out:
# {'a', 'i', 'o', 'u'}

# %%
set3.intersection(set4)
# Out:
# {'a', 'i', 'o', 'u'}

# %%
set3.intersection_update(set4)

# %%
set3
# Out:
# {'a', 'i', 'o', 'u'}

# %%
set4
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %%
set3.isdisjoint(set2)
# Out:
# True

# %%
set3.issubset(set4)
# Out:
# True

# %%
set3.issuperset(set4)
# Out:
# False

# %%
set3.symmetric_difference(set4)
# Out:
# {'e'}

# %%
set3.symmetric_difference_update(set4)

# %%
set3
# Out:
# {'e'}

# %%
set4
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %%
set4.pop()
# Out:
# 'i'

# %%
set4
# Out:
# {'a', 'e', 'o', 'u'}

# %%
set4.union()
# Out:
# {'a', 'e', 'o', 'u'}

# %%
set4.union(set3)
# Out:
# {'a', 'e', 'o', 'u'}

# %%
set3.union(set4)
# Out:
# {'a', 'e', 'o', 'u'}

# %%
set4
# Out:
# {'a', 'e', 'o', 'u'}

# %%
set3
# Out:
# {'e'}

# %%
set4.update(set3)

# %%
set3
# Out:
# {'e'}

# %%
set4
# Out:
# {'a', 'e', 'o', 'u'}

# %%
set3.update(set4)

# %%
set3
# Out:
# {'a', 'e', 'o', 'u'}

# %%
set3 == set4
# Out:
# True

# %%
set3.pop()
# Out:
# 'u'

# %%
set3
# Out:
# {'a', 'e', 'o'}

# %%
set3.clear()

# %%
set3
# Out:
# set()

# %% [markdown]
# # Dictionaries

# %%
dict1 = {
    'name' : "Rama",
    'son' : "Krishna",
    'daughter' : "Amma"
}

# %%
dict1.items()
# Out:
# dict_items([('name', 'Rama'), ('son', 'Krishna'), ('daughter', 'Amma')])

# %%
dict1.keys()
# Out:
# dict_keys(['name', 'son', 'daughter'])

# %%
dict1.fromkeys('name')
# Out:
# {'n': None, 'a': None, 'm': None, 'e': None}

# %%
dict1.get('name')
# Out:
# 'Rama'

# %%
dict1.setdefault('name1', "Rama")
# Out:
# 'Rama'

# %%
'Naana' in dict1
# Out:
# False

# %%
dict1.update({'daughter' : 'Kamakshamma'})

# %%
dict1
# Out:
# {'name': 'Rama', 'son': 'Krishna', 'daughter': 'Kamakshamma', 'name1': 'Rama'}

# %%
dict1.popitem()
# Out:
# ('name1', 'Rama')

# %%
dict1.setdefault('name2' , "Sathi")
# Out:
# 'Sathi'

# %%
dict1
# Out:
# {'name': 'Rama', 'son': 'Krishna', 'daughter': 'Kamakshamma', 'name2': 'Sathi'}

# %%
dict1.pop('name2')
# Out:
# 'Sathi'

# %%
dict1
# Out:
# {'name': 'Rama', 'son': 'Krishna', 'daughter': 'Kamakshamma'}

# %%
dict2 = dict1.copy()

# %%
print(dict1)
print(dict2)
# Out:
# {'name': 'Rama', 'son': 'Krishna', 'daughter': 'Kamakshamma'}
# {'name': 'Rama', 'son': 'Krishna', 'daughter': 'Kamakshamma'}

# %%
dict1 == dict2
# Out:
# True

# %%
dict2.clear()

# %%
dict2
# Out:
# {}
